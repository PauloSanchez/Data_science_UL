# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloSanchez/Data_science_UL/blob/main/Cambio_de_nombre%2C_borrado_y_NaN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/RailsToTrails_National_Count_Data_week.xlsx')
df
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 0     Week 1 2020-12-30                    167679.0
# 1     Week 2 2020-01-06                     82340.0
# 2     Week 3 2020-01-13                     62315.0
# 3     Week 4 2020-01-20                     75801.0
# 4     Week 5 2020-01-27                     75841.0
# 5     Week 6 2020-02-03                     79780.0
# 6     Week 7 2020-02-10                     65732.0
# 7     Week 8 2020-02-17                     69492.0
# 8     Week 9 2020-02-24                     85688.0
# 9    Week 10 2020-03-02                     84512.0
# 10   Week 11 2020-03-09                    107995.0
# 11   Week 12 2020-03-16                    125440.0
# 12   Week 13 2020-03-23                    136330.0
# 13   Week 14 2020-03-30                    118784.0
# 14   Week 15 2020-04-06                    132033.0
# 15   Week 16 2020-04-13                    133267.0
# 16   Week 17 2020-04-20                    165777.0
# ...

# %%
#1-Se eliminan las columnas indicadas.
df=df.drop(columns=['Unnamed: 7','Unnamed: 8','Unnamed: 9'])
df.head()
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                    167679.0
# 1    Week 2 2020-01-06                     82340.0
# 2    Week 3 2020-01-13                     62315.0
# 3    Week 4 2020-01-20                     75801.0
# 4    Week 5 2020-01-27                     75841.0
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6
# 0                    183546.0          NaN          0.094627    1.094627
# 1                     97140.0          NaN          0.179743  117.974253
# 2                     75782.0          NaN          0.216112  121.611169
# 3                     83809.0          NaN          0.105645  110.564504
# 4                     94738.0          NaN          0.249166  124.916602

# %%
#2- Se cambia el nombre de la columna.
df.columns=['Timeframe','Week of','2019 counts (31 counters)','2020 counts (31 counters)','2021 Counts','Change 2019-2020','Percent_change']
df.head()
# Out:
#   Timeframe    Week of  2019 counts (31 counters)  2020 counts (31 counters)  \
# 0    Week 1 2020-12-30                   167679.0                   183546.0
# 1    Week 2 2020-01-06                    82340.0                    97140.0
# 2    Week 3 2020-01-13                    62315.0                    75782.0
# 3    Week 4 2020-01-20                    75801.0                    83809.0
# 4    Week 5 2020-01-27                    75841.0                    94738.0
#
#    2021 Counts  Change 2019-2020  Percent_change
# 0          NaN          0.094627        1.094627
# 1          NaN          0.179743      117.974253
# 2          NaN          0.216112      121.611169
# 3          NaN          0.105645      110.564504
# 4          NaN          0.249166      124.916602

# %%
#3-Conteo de nulos e identificación de columna.
NaN=df.isnull().sum(axis=0) # Cuenta los datos NaN en la columna.
NaN
# Out:
# Timeframe                     0
# Week of                       0
# 2019 counts (31 counters)     0
# 2020 counts (31 counters)     0
# 2021 Counts                  52
# Change 2019-2020              0
# Percent_change                0
# dtype: int64

# %%
#4- Se reemplazan los nulos o faltantes de la columna por un cero
df=df.fillna(0)
df.head()
# Out:
#   Timeframe    Week of  2019 counts (31 counters)  2020 counts (31 counters)  \
# 0    Week 1 2020-12-30                   167679.0                   183546.0
# 1    Week 2 2020-01-06                    82340.0                    97140.0
# 2    Week 3 2020-01-13                    62315.0                    75782.0
# 3    Week 4 2020-01-20                    75801.0                    83809.0
# 4    Week 5 2020-01-27                    75841.0                    94738.0
#
#    2021 Counts  Change 2019-2020  Percent_change
# 0          0.0          0.094627        1.094627
# 1          0.0          0.179743      117.974253
# 2          0.0          0.216112      121.611169
# 3          0.0          0.105645      110.564504
# 4          0.0          0.249166      124.916602
