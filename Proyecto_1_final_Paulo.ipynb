# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloSanchez/Data_science_UL/blob/main/Proyecto_1_final_Paulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Diccionario para el proyecto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Analisis exploratorio

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Archivos ejercicios/sales_predictions.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
#Analisis exploratorio para saber si hay datos Nan y los tipos de datos que tenemos en cada columna.
df.info()
#Como se observa la columna item weight y Outlet_Size tienen NaN, por lo que debemos revisar cuale y cuantos son y de que manera procedemos a completar o eliminar de la data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#Definiremos aquellos que son nulos y los que no, para ver que correlación hay con otras columnas del DF.
nulos=df[df.Outlet_Size.isnull()]
nulos
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# 8              Frozen Foods   96.9726            OUT045
# 9              Frozen Foods  187.8214            OUT017
# 25                Household   45.9060            OUT017
# 28                    Dairy   45.5086            OUT010
# ...                     ...       ...               ...
# 8502              Household  216.4192            OUT045
# 8508  Fruits and Vegetables  199.4742            OUT045
# 8509  Fruits and Vegetables  213.9902            OUT010
# 8514                 Canned   57.5904            OUT045
# 8519           Baking Goods  108.1570            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                          1998         NaN               Tier 3
# 8                          2002         NaN               Tier 2
# 9                          2007         NaN               Tier 2
# 25                         2007         NaN               Tier 2
# 28                         1998         NaN               Tier 3
# ...                         ...         ...                  ...
# 8502                       2002         NaN               Tier 2
# 8508                       2002         NaN               Tier 2
# 8509                       1998         NaN               Tier 3
# 8514                       2002         NaN               Tier 2
# 8519                       2002         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 3         Grocery Store           732.3800
# 8     Supermarket Type1          1076.5986
# 9     Supermarket Type1          4710.5350
# 25    Supermarket Type1           838.9080
# 28        Grocery Store           178.4344
# ...                 ...                ...
# 8502  Supermarket Type1          3020.0688
# 8508  Supermarket Type1          2587.9646
# 8509      Grocery Store           424.7804
# 8514  Supermarket Type1           468.7232
# 8519  Supermarket Type1           549.2850
#
# [2410 rows x 12 columns]

# %%
nulos.groupby(['Outlet_Identifier'])[['Outlet_Size']].count()
#Se observan que solo tres sucursales no tienen el dato.
# Out:
#                    Outlet_Size
# Outlet_Identifier
# OUT010                       0
# OUT017                       0
# OUT045                       0

# %%
#Identificar los que no son nulos, filtrando
nonulos=df[df.Outlet_Size.notnull()]
nonulos
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# ...                  ...       ...               ...
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 4                          1987        High               Tier 3
# 5                          2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 4     Supermarket Type1           994.7052
# 5     Supermarket Type2           556.6088
# ...                 ...                ...
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [6113 rows x 12 columns]

# %%
nonulos.groupby(['Outlet_Size','Outlet_Identifier'])[['Outlet_Size']].count()
# Out:
#                                Outlet_Size
# Outlet_Size Outlet_Identifier
# High        OUT013                     932
# Medium      OUT018                     928
#             OUT027                     935
#             OUT049                     930
# Small       OUT019                     528
#             OUT035                     930
#             OUT046                     930

# %% [markdown]
# La columna Outlet_Size, tiene NaN pero es por que hay tres sucursales de outlet cuyo Outlet_Identifier, no reportan en ninguna fila un valor para la columna mencionada inicialmente, por lo que se determina dejar en blanco y no utilizar el tamaño sino, más bien el identificador de la sucursal.

# %%
#Se procede a explorar la columna de numeros enteros denominada "Item_Weight", para determinar que se hará con los datos.

weightnull=df[df.Item_Weight.isnull()]
weightnull
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# 18              Hard Drinks  113.2834            OUT027
# 21             Baking Goods  144.5444            OUT027
# 23             Baking Goods  107.6938            OUT019
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8485            Soft Drinks  189.0530            OUT027
# 8487            Soft Drinks  164.7526            OUT027
# 8488                 Others  184.6608            OUT027
# 8490  Fruits and Vegetables  162.3552            OUT019
# 8504              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7                          1985      Medium               Tier 3
# 18                         1985      Medium               Tier 3
# 21                         1985      Medium               Tier 3
# 23                         1985       Small               Tier 1
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 8485                       1985      Medium               Tier 3
# 8487                       1985      Medium               Tier 3
# 8488                       1985      Medium               Tier 3
# 8490                       1985       Small               Tier 1
# 8504                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 7     Supermarket Type3          4022.7636
# 18    Supermarket Type3          2303.6680
# 21    Supermarket Type3          4064.0432
# 23        Grocery Store           214.3876
# 29        Grocery Store           125.8362
# ...                 ...                ...
# 8485  Supermarket Type3          6261.8490
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8490      Grocery Store           487.3656
# 8504  Supermarket Type3          4138.6128
#
# [1463 rows x 12 columns]

# %%
#Se procede a explorar la columna de numeros enteros denominada "Item_Weight", para determinar que se hará con los datos.

weightnotnull=df[df.Item_Weight.notnull()]
weightnotnull.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
filtroitem=df['Item_Identifier']=='DRI11'
filtroitem
df1=df.loc[filtroitem, :]
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 18             DRI11          NaN          Low Fat         0.034238
# 1366           DRI11          NaN          Low Fat         0.060237
# 3127           DRI11         8.26          Low Fat         0.034458
# 5310           DRI11         8.26          Low Fat         0.057586
# 7022           DRI11         8.26          Low Fat         0.034398
# 7192           DRI11         8.26          Low Fat         0.034544
# 8483           DRI11         8.26          Low Fat         0.034474
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 18    Hard Drinks  113.2834            OUT027                       1985
# 1366  Hard Drinks  115.9834            OUT019                       1985
# 3127  Hard Drinks  113.3834            OUT049                       1999
# 5310  Hard Drinks  113.7834            OUT010                       1998
# 7022  Hard Drinks  115.7834            OUT035                       2004
# 7192  Hard Drinks  116.0834            OUT018                       2009
# 8483  Hard Drinks  117.0834            OUT045                       2002
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 18        Medium               Tier 3  Supermarket Type3          2303.6680
# 1366       Small               Tier 1      Grocery Store           345.5502
# 3127      Medium               Tier 1  Supermarket Type1          2073.3012
# 5310         NaN               Tier 3      Grocery Store           115.1834
# 7022       Small               Tier 2  Supermarket Type1          2073.3012
# 7192      Medium               Tier 3  Supermarket Type2          1267.0174
# 8483         NaN               Tier 2  Supermarket Type1          1612.5676

# %% [markdown]
# Se aprecia que al filtrar un Item_identifier, el peso del item es el mismo dado que el identifier es el codigo del producto y el peso obviamente es el mismo, por lo que con el promedio de estos excluyendo los nulos podré obtener el valor a reemplazar.

# %% [markdown]
# #Reemplazar Nulos y eliminar duplicados

# %%
weightnotnull.groupby(['Item_Identifier'])[['Item_Weight']].mean()
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %% [markdown]
# Creamos un groupby con la media para obtener el valor a reemplazar en los null

# %%
df11=df

# %%
#Función para rellenar NaN con un groupby en pandas

def rellenar_nan(x):
  ids = set(x.dropna())
  if not ids:
    # Conjunto vacío, nada que hacer
    print(x.name, "era todo NaN")
    return x
  if len(ids)>1:
    # Posible problema si además contiene Nan
    if sum(x.isnull()) > 0:
      print("Cuidado!", x.name, "tiene varias posibilidades", ids)
  # Extraemos uno de los elementos del conjunto y lo usamos para rellenar  
  id = ids.pop()
  return x.fillna(id)

# %% [markdown]
# Aplicamos la función para que podamos reemplazar con pandas y un groupby los datos nulos

# %%
df11.loc[:, "Item_Weight"] = \
   df11.groupby("Item_Identifier")["Item_Weight"].apply(rellenar_nan)
# Out:
# FDE52 era todo NaN
# FDK57 era todo NaN
# FDN52 era todo NaN
# FDQ60 era todo NaN

# %%
df11.loc[:, "Outlet_Size"] = \
   df11.groupby("Outlet_Identifier")["Outlet_Size"].apply(rellenar_nan)
# Out:
# OUT010 era todo NaN
# OUT017 era todo NaN
# OUT045 era todo NaN

# %% [markdown]
# Una vez aplicada la función, nos dirá cuales erán los Item Identifier que no tenian en ninguna fila un dato, mismo para el codigo de outlet. y en el caso de outlet_size todas las filas para el mismo codigo de outlet estaban vacías o con datos nulos.

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8519 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# Al parecer son muchas filas que tienen datos nulos para el outlet_size, verificaremos cuanto representa en el total de la data.

# %%
#Porcentajes de NaN restantes en Item_Weight
# import numpy as np
Completo=df11['Item_Identifier'].count()

NaN=df11['Item_Weight'].isnull().sum(axis=0) # Cuenta los datos NaN en la columna.

#Entonces el porcentaje es:

Percent=NaN/Completo
p=Percent*100
print('El total de NaN dentro del DataFrame representa el',p,'%')
# Out:
# El total de NaN dentro del DataFrame representa el 0.04693183151472486 %

# %% [markdown]
# Se observa que no se pueden eliminar todos los nulos puesto que hay 4 filas que no se rellenan, dado que todo era NaN, por lo que al mirar que los NaN solo representan el 0.05% aprox, se define eliminar de la data esas filas, pues no hay como rellenarlas. Por ultimo debemos hacer lo mismo para la columna Outlet_Size.

# %%
#Porcentajes de NaN restantes en Outlet_Size
import numpy as np
Completo1=df11['Item_Identifier'].count()

NaN1=df11['Outlet_Size'].isnull().sum(axis=0) # Cuenta los datos NaN en la columna.

#Entonces el porcentaje es:

Percent1=NaN1/Completo1
p1=Percent1*100
print('El total de NaN dentro del DataFrame representa el',p1,'%')
# Out:
# El total de NaN dentro del DataFrame representa el 28.27642848762173 %

# %%
#Rellenar una columna con NaN al valor 'No definido'

values = {"Outlet_Size": 'No definido'} #Se debe crear un diccionario para reemplazar en la columna
df11=df11.fillna(value=values)
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8519 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# Se relleno todos los tamaños de outlet por la frase 'No definido' dado que no tenemos otros Outlet_Identifier de donde obtener la data y la cantidad de filas supera el 10% del total.

# %%
#Eliminar las 4 filas restantes con NaN

df11=df11.dropna()
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8519 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8519 non-null   object
#  1   Item_Weight                8519 non-null   float64
#  2   Item_Fat_Content           8519 non-null   object
#  3   Item_Visibility            8519 non-null   float64
#  4   Item_Type                  8519 non-null   object
#  5   Item_MRP                   8519 non-null   float64
#  6   Outlet_Identifier          8519 non-null   object
#  7   Outlet_Establishment_Year  8519 non-null   int64
#  8   Outlet_Size                8519 non-null   object
#  9   Outlet_Location_Type       8519 non-null   object
#  10  Outlet_Type                8519 non-null   object
#  11  Item_Outlet_Sales          8519 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 865.2+ KB

# %% [markdown]
# Con esto se termina de limpiar y ordenar la base de datos!!

# %% [markdown]
# #Visualizaciones

# %%
df11.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Outlet_Size Outlet_Location_Type  \
# 0                       1999       Medium               Tier 1
# 1                       2009       Medium               Tier 3
# 2                       1999       Medium               Tier 1
# 3                       1998  No definido               Tier 3
# 4                       1987         High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
#Importamos las librerias
import numpy as np
import matplotlib.pyplot as plt

# %%
datagroup1=df.groupby(['Outlet_Identifier'])['Item_Identifier'].count()
x=np.array(datagroup1.index)
y=np.array(datagroup1.values)

# %%
#Graficamos
plt.suptitle("Grafico 1", fontsize=20, fontweight="bold")
plt.style.use('seaborn')
plt.bar(x,y)
plt.xticks(rotation=45)
plt.title('Cantidad de Item vendidos por tienda', fontsize=15)
plt.xlabel('Codigo de tienda',fontsize=15)
plt.ylabel('Cantidad de Item vendidos', fontsize=15)
plt.ylim(0,1200)
plt.plot([800,800,800,800,800,800,800,800,800,800], 'r--o')
plt.legend(['Target','Cantidad Vendida'],bbox_to_anchor=(1.1,0.5))

# %% [markdown]
# Podemos observar que del total de las sucursales, la mayoría supera los 800 item vendidos, salvo dos de ellos que a penas superan los 500.
#
# Además agregué un Target de ventas como linea roja segmentada.

# %%
datagroup2=df11.groupby(['Outlet_Identifier'])['Item_Outlet_Sales'].sum()
a=np.array(datagroup2.index)
b=np.array(datagroup2.values)

# %%
plt.style.use('seaborn')
plt.suptitle("Grafico 2", fontsize=20, fontweight="bold")
plt.title('Ventas (USD) por tienda')
plt.xlabel('Código de tienda')
plt.ylabel('Ventas en USD')
plt.grid(False)
plt.plot(a,b, 'b-o')
plt.xticks(rotation=45)
plt.legend(['Ventas'], bbox_to_anchor=(1.2,0.3))
plt.ylim(0,3600000)
# Out:
# (0.0, 3600000.0)

# %%
datagroup3=df11.groupby(['Outlet_Type'])['Item_Outlet_Sales'].sum()
c=np.array(datagroup3.index)
d=np.array(datagroup3.values)

# %%
#Gráfico de torta

explotar = [0, 0.1, 0, 0] #sirve para destacar alguna porcion. El valor es cuanto se separa de la torta.

fig1 = plt.figure(dpi=100)
ax1 = fig1.add_subplot(1,1,1) 
plt.suptitle("Grafico 3", fontsize=20, fontweight="bold")
ax1.pie(d, labels=c, explode=explotar, autopct="%.1f%%", shadow = False, startangle=45)
# autopct = porcentaje automático; shadow = grafico con sombra; startangle = ángulo de inicio
# %.2f%% formato de decimal, viene del lenguaje C. Sí, python está escrito en C.
plt.title('Participación % por tipo de Outlet')
ax1.axis("equal") #asegura proporcion igualitaria, vale decir, suma de porcentajes 100% (círculo)

plt.show()

# %% [markdown]
# #Parte 4 Histogramas, cajas y otros.

# %%
#Histograma 

ventas=df11['Item_Outlet_Sales']
visibilidad=df11['Item_Visibility']

#Figura1
fig1 = plt.figure(dpi=150)

ax1 = fig1.add_subplot(1,2,1)
ax1.hist(ventas, color='darkorange')
plt.suptitle("Grafico 4", fontsize=20, fontweight="bold")
plt.style.use('seaborn')
plt.title('Ventas de productos', fontsize = 15)
plt.grid(True)
plt.xlabel('Porcentaje', fontsize = 12)
plt.ylabel('Cantidad', fontsize = 12)


#Figura2
ax2 = fig1.add_subplot(1,2,2)
ax2.hist(visibilidad, color='blue', alpha=0.5)
plt.suptitle("Grafico 4", fontsize=20, fontweight="bold")
plt.style.use('seaborn')
plt.title('Porcentaje de Visibilidad', fontsize = 15)
plt.grid(True)
plt.xlabel('Porcentaje', fontsize = 12)
plt.ylabel('Cantidad', fontsize = 12)

#plt.legend('Histograma ventas','Histograma % Visibildiad', ) #Intenté colocar legenda pero no me permite.
# Out:
# Text(0, 0.5, 'Cantidad')

# %% [markdown]
# Se observa una clara correlación al comparar ambos histogramas tanto de las ventas como la visibilidad, por lo que al realizar una regresión lineal podemos utilizar ambos daatos para correlacionar y proyectar ventas en lo psoible.

# %%
#Diagrama de caja

plt.style.use('seaborn')
plt.title('', fontsize = 18)
plt.grid(False)
plt.ylabel('Cantidad', fontsize = 12)
plt.boxplot(ventas,   widths = .7, patch_artist=True,
            medianprops = dict(linestyle='-', linewidth=2, color='Yellow'), boxprops = dict(linestyle='--', 
                                                                                            linewidth=2, color='Black', facecolor = 'blue', alpha = .4))
plt.grid(True)
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
#Diagrama de caja

plt.style.use('seaborn')
plt.title('', fontsize = 18)
plt.grid(False)
plt.ylabel('Cantidad', fontsize = 12)
plt.boxplot(visibilidad, widths = .7, patch_artist=True,
            medianprops = dict(linestyle='-', linewidth=2, color='blue'), boxprops = dict(linestyle='--', 
                                                                                            linewidth=2, color='Black', facecolor = 'yellow', alpha = .4))
plt.grid(True)
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# #Regresión Lineal - proyecciónes de ventas

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8519 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8519 non-null   object
#  1   Item_Weight                8519 non-null   float64
#  2   Item_Fat_Content           8519 non-null   object
#  3   Item_Visibility            8519 non-null   float64
#  4   Item_Type                  8519 non-null   object
#  5   Item_MRP                   8519 non-null   float64
#  6   Outlet_Identifier          8519 non-null   object
#  7   Outlet_Establishment_Year  8519 non-null   int64
#  8   Outlet_Size                8519 non-null   object
#  9   Outlet_Location_Type       8519 non-null   object
#  10  Outlet_Type                8519 non-null   object
#  11  Item_Outlet_Sales          8519 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 865.2+ KB

# %%
#Identificar las variables que se correlacionan fuertemente con la variable objetivo:

corr = df11.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d79b3_row0_col0, #T_d79b3_row1_col1, #T_d79b3_row2_col2, #T_d79b3_row3_col3, #T_d79b3_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d79b3_row0_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_d79b3_row0_col2, #T_d79b3_row4_col0, #T_d79b3_row4_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_d79b3_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_d79b3_row0_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d79b3_row1_col0, #T_d79b3_row3_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d79b3_row1_col2, #T_d79b3_row1_col3, #T_d79b3_row1_col4, #T_d79b3_row3_col0, #T_d79b3_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d79b3_row2_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d79b3_row2_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d79b3_row2_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d79b3_row2_col4 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_d79b3_row3_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_d79b3_row3_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_d79b3_row4_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# </style>
# <table id="T_d79b3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Item_Weight</th>
#       <th class="col_heading level0 col1" >Item_Visibility</th>
#       <th class="col_heading level0 col2" >Item_MRP</th>
#       <th class="col_heading level0 col3" >Outlet_Establishment_Year</th>
#       <th class="col_heading level0 col4" >Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d79b3_level0_row0" class="row_heading level0 row0" >Item_Weight</th>
#       <td id="T_d79b3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d79b3_row0_col1" class="data row0 col1" >-0.009173</td>
#       <td id="T_d79b3_row0_col2" class="data row0 col2" >0.025975</td>
#       <td id="T_d79b3_row0_col3" class="data row0 col3" >-0.013426</td>
#       <td id="T_d79b3_row0_col4" class="data row0 col4" >0.013168</td>
#     </tr>
#     <tr>
#       <th id="T_d79b3_level0_row1" class="row_heading level0 row1" >Item_Visibility</th>
#       <td id="T_d79b3_row1_col0" class="data row1 col0" >-0.009173</td>
#       <td id="T_d79b3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d79b3_row1_col2" class="data row1 col2" >-0.001155</td>
#       <td id="T_d79b3_row1_col3" class="data row1 col3" >-0.074325</td>
#       <td id="T_d79b3_row1_col4" class="data row1 col4" >-0.128297</td>
#     </tr>
#     <tr>
#       <th id="T_d79b3_level0_row2" class="row_heading level0 row2" >Item_MRP</th>
#       <td id="T_d79b3_row2_col0" class="data row2 col0" >0.025975</td>
#       <td id="T_d79b3_row2_col1" class="data row2 col1" >-0.001155</td>
#       <td id="T_d79b3_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d79b3_row2_col3" class="data row2 col3" >0.004599</td>
#       <td id="T_d79b3_row2_col4" class="data row2 col4" >0.567803</td>
#     </tr>
#     <tr>
#       <th id="T_d79b3_level0_row3" class="row_heading level0 row3" >Outlet_Establishment_Year</th>
#       <td id="T_d79b3_row3_col0" class="data row3 col0" >-0.013426</td>
#       <td id="T_d79b3_row3_col1" class="data row3 col1" >-0.074325</td>
#       <td id="T_d79b3_row3_col2" class="data row3 col2" >0.004599</td>
#       <td id="T_d79b3_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d79b3_row3_col4" class="data row3 col4" >-0.049083</td>
#     </tr>
#     <tr>
#       <th id="T_d79b3_level0_row4" class="row_heading level0 row4" >Item_Outlet_Sales</th>
#       <td id="T_d79b3_row4_col0" class="data row4 col0" >0.013168</td>
#       <td id="T_d79b3_row4_col1" class="data row4 col1" >-0.128297</td>
#       <td id="T_d79b3_row4_col2" class="data row4 col2" >0.567803</td>
#       <td id="T_d79b3_row4_col3" class="data row4 col3" >-0.049083</td>
#       <td id="T_d79b3_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Se observa que hay corelación entre algunas variables, ya que las demás son categoricas, por tanto, se deben tratar primero las variables categoricas antes de mirar sus correlaciones.

# %%
#Con esto se convierten a numero las variables categoricas.
df11['Item_Identifier'] = pd.factorize(df11['Item_Identifier'])[0]
df11['Item_Fat_Content'] = pd.factorize(df11['Item_Fat_Content'])[0]
df11['Item_Type'] = pd.factorize(df11['Item_Type'])[0]
df11['Outlet_Identifier'] = pd.factorize(df11['Outlet_Identifier'])[0]
df11['Outlet_Size'] = pd.factorize(df11['Outlet_Size'])[0]
df11['Outlet_Location_Type'] = pd.factorize(df11['Outlet_Location_Type'])[0]
df11['Outlet_Type'] = pd.factorize(df11['Outlet_Type'])[0]

# %%
#Identificar las variables que se correlacionan fuertemente con la variable objetivo:
#Miramos nuevamente las correlaciones.
corr = df11.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6e7a5_row0_col0, #T_6e7a5_row1_col1, #T_6e7a5_row2_col2, #T_6e7a5_row3_col3, #T_6e7a5_row4_col4, #T_6e7a5_row5_col5, #T_6e7a5_row6_col6, #T_6e7a5_row7_col7, #T_6e7a5_row8_col8, #T_6e7a5_row9_col9, #T_6e7a5_row10_col10, #T_6e7a5_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6e7a5_row0_col1, #T_6e7a5_row1_col0, #T_6e7a5_row1_col2, #T_6e7a5_row1_col4, #T_6e7a5_row4_col2, #T_6e7a5_row4_col5, #T_6e7a5_row5_col4, #T_6e7a5_row7_col6, #T_6e7a5_row7_col10, #T_6e7a5_row8_col11, #T_6e7a5_row10_col7, #T_6e7a5_row10_col8, #T_6e7a5_row10_col9, #T_6e7a5_row11_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6e7a5_row0_col2, #T_6e7a5_row8_col4, #T_6e7a5_row9_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6e7a5_row0_col3, #T_6e7a5_row8_col10 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6e7a5_row0_col4, #T_6e7a5_row10_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_6e7a5_row0_col5, #T_6e7a5_row1_col5, #T_6e7a5_row3_col0, #T_6e7a5_row6_col0, #T_6e7a5_row9_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_6e7a5_row0_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_6e7a5_row0_col7 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6e7a5_row0_col8, #T_6e7a5_row5_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_6e7a5_row0_col9, #T_6e7a5_row4_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6e7a5_row0_col10 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_6e7a5_row0_col11, #T_6e7a5_row1_col11, #T_6e7a5_row2_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_6e7a5_row1_col3 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_6e7a5_row1_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_6e7a5_row1_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_6e7a5_row1_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_6e7a5_row1_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6e7a5_row1_col10, #T_6e7a5_row4_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_6e7a5_row2_col0, #T_6e7a5_row7_col0, #T_6e7a5_row8_col0, #T_6e7a5_row11_col0, #T_6e7a5_row11_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6e7a5_row2_col1, #T_6e7a5_row6_col4, #T_6e7a5_row6_col5, #T_6e7a5_row7_col1, #T_6e7a5_row7_col5, #T_6e7a5_row9_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_6e7a5_row2_col4, #T_6e7a5_row3_col4, #T_6e7a5_row8_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_6e7a5_row2_col5, #T_6e7a5_row7_col2, #T_6e7a5_row10_col2, #T_6e7a5_row10_col5, #T_6e7a5_row11_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_6e7a5_row2_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_6e7a5_row2_col7, #T_6e7a5_row2_col10, #T_6e7a5_row5_col7, #T_6e7a5_row11_col10 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_6e7a5_row2_col8, #T_6e7a5_row4_col8 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_6e7a5_row2_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6e7a5_row2_col11, #T_6e7a5_row4_col11 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_6e7a5_row3_col1, #T_6e7a5_row8_col5, #T_6e7a5_row9_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_6e7a5_row3_col2, #T_6e7a5_row6_col1, #T_6e7a5_row9_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_6e7a5_row3_col5, #T_6e7a5_row10_col0, #T_6e7a5_row10_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_6e7a5_row3_col6, #T_6e7a5_row8_col9, #T_6e7a5_row10_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_6e7a5_row3_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_6e7a5_row3_col8 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_6e7a5_row3_col9, #T_6e7a5_row6_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_6e7a5_row3_col10 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_6e7a5_row3_col11, #T_6e7a5_row4_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_6e7a5_row4_col0, #T_6e7a5_row5_col0, #T_6e7a5_row5_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6e7a5_row4_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_6e7a5_row4_col6, #T_6e7a5_row5_col6, #T_6e7a5_row7_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_6e7a5_row4_col10 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_6e7a5_row5_col2, #T_6e7a5_row6_col2, #T_6e7a5_row10_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6e7a5_row5_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_6e7a5_row5_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_6e7a5_row5_col10 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_6e7a5_row5_col11 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_6e7a5_row6_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_6e7a5_row6_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_6e7a5_row6_col8 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_6e7a5_row6_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_6e7a5_row6_col10 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_6e7a5_row7_col3, #T_6e7a5_row8_col1, #T_6e7a5_row11_col6 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6e7a5_row7_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_6e7a5_row7_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6e7a5_row7_col9 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_6e7a5_row8_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_6e7a5_row8_col6 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_6e7a5_row8_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6e7a5_row9_col2, #T_6e7a5_row11_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_6e7a5_row9_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_6e7a5_row9_col7 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_6e7a5_row9_col8, #T_6e7a5_row10_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_6e7a5_row9_col10, #T_6e7a5_row9_col11 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_6e7a5_row11_col5 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_6e7a5_row11_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_6e7a5_row11_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6e7a5_row11_col9 {
#   background-color: #8badfd;
#   color: #000000;
# }
# </style>
# <table id="T_6e7a5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Item_Identifier</th>
#       <th class="col_heading level0 col1" >Item_Weight</th>
#       <th class="col_heading level0 col2" >Item_Fat_Content</th>
#       <th class="col_heading level0 col3" >Item_Visibility</th>
#       <th class="col_heading level0 col4" >Item_Type</th>
#       <th class="col_heading level0 col5" >Item_MRP</th>
#       <th class="col_heading level0 col6" >Outlet_Identifier</th>
#       <th class="col_heading level0 col7" >Outlet_Establishment_Year</th>
#       <th class="col_heading level0 col8" >Outlet_Size</th>
#       <th class="col_heading level0 col9" >Outlet_Location_Type</th>
#       <th class="col_heading level0 col10" >Outlet_Type</th>
#       <th class="col_heading level0 col11" >Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e7a5_level0_row0" class="row_heading level0 row0" >Item_Identifier</th>
#       <td id="T_6e7a5_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6e7a5_row0_col1" class="data row0 col1" >-0.049701</td>
#       <td id="T_6e7a5_row0_col2" class="data row0 col2" >0.015371</td>
#       <td id="T_6e7a5_row0_col3" class="data row0 col3" >0.005688</td>
#       <td id="T_6e7a5_row0_col4" class="data row0 col4" >0.027999</td>
#       <td id="T_6e7a5_row0_col5" class="data row0 col5" >0.027533</td>
#       <td id="T_6e7a5_row0_col6" class="data row0 col6" >0.004447</td>
#       <td id="T_6e7a5_row0_col7" class="data row0 col7" >0.014030</td>
#       <td id="T_6e7a5_row0_col8" class="data row0 col8" >0.012218</td>
#       <td id="T_6e7a5_row0_col9" class="data row0 col9" >0.006647</td>
#       <td id="T_6e7a5_row0_col1

# %%
#Definimos las variables.
X = df11.drop(columns=['Item_Identifier',	'Item_Weight',	'Item_Fat_Content','Item_Visibility', 'Item_Type',
                      'Outlet_Identifier', 'Item_Outlet_Sales'])
y = df11['Item_Outlet_Sales'].values

#Spliteamos el modelo.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

from sklearn.preprocessing import MinMaxScaler 
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test) # Ojo: escalamiento de test se hace en base al train

# %%
from sklearn.linear_model import LinearRegression

lr= LinearRegression()
lr.fit(X_train, y_train)
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.38909890831494665

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=3)

knn.fit(X_train,y_train)
knn_y_pred = knn.predict(X_train)
knn.score(X_test, y_test)
# Out:
# 0.47301918248386365

# %% [markdown]
# Segun el R Cuadrado del modelo con regresion lineal y el accuracy de KNN ambos modelos estan por debajo de lo que podemos llamar un buen modelo, sin embargo, con Knn se obtuvo un mejor acurracy.
